# %%
from main import downloadData
from main import run_LSTM, print_pred

# %%
df = downloadData('AAPL','2018-01-01')
#Available features 'Volume', 'RSI', 'ATR'
features =['RSI']
run_LSTM(df, features)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Overview of data:
#                 Close        rsi
# Date
# 2018-01-23  42.246162  68.998426
# 2018-01-24  41.573235  55.580661
# 2018-01-25  40.831116  45.152409
# 2018-01-26  40.926556  46.541547
# 2018-01-29  40.079441  37.470218
#
#
# Overview of scaled data:
# [[0.07845173 0.73857598]
#  [0.07168928 0.52886061]
#  [0.0642315  0.36587037]
#  [0.06519061 0.38758215]]
#
#
# Training model...
# 520/520 - 17s - loss: 0.0022
# Root Mean Squared Error = 6.048164816127441

# %%
print_pred()
# Out:
#                  Close        rsi  Predictions
# Date
# 2020-05-13   76.641853  63.839751    80.097176
# 2020-05-14   77.112686  64.731770    80.919037
# 2020-05-15   76.656792  63.108419    81.632011
# 2020-05-18   78.462914  66.674113    82.192924
# 2020-05-19   78.009521  64.976325    82.778244
# 2020-05-20   79.526665  67.920050    83.297462
# 2020-05-21   78.933754  65.599539    83.873924
# 2020-05-22   79.441963  66.651266    84.387474
# 2020-05-26   78.903862  64.405983    84.883904
# 2020-05-27   79.247643  65.212272    85.278778
# 2020-05-28   79.282524  65.298166    85.625320
# 2020-05-29   79.205299  64.916014    85.928673
# 2020-06-01   80.179359  67.499684    86.180573
# 2020-06-02   80.550545  68.453083    86.482536
# 2020-06-03   80.993980  69.600390    86.832840
# 2020-06-04   80.296448  65.561253    87.235916
# 2020-06-05   82.583374  71.417837    87.541473
# 2020-06-08   83.071640  72.493369    87.987473
# 2020-06-09   85.694878  77.411328    88.533363
# ...
